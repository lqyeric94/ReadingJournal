# %% [markdown]
# # Day 8 Reading Journal
#
# This journal includes several required exercises, but it is meant to encourage active reading more generally.  You should use the journal to take detailed notes, catalog questions, and explore the content from Think Python deeply.
#
# Reading: Think Python Chapter 12
#
# **Due: Thursday, September 29 at 12 noon**

# %% [markdown]
# ## [Chapter 12](http://www.greenteapress.com/thinkpython/html/thinkpython013.html)

# %% [markdown]
# ### Exercise 2
# Exercise 12.2. In this example, ties are broken by comparing words, so words with the same length appear in reverse alphabetical order. For other applications you might want to break ties at ran- dom. Modify this example so that words with the same length appear in random order. Hint: see the random function in the random module.

# %%
import random

def sort_by_length(words):
    t = []
    for word in words:
       t.append((len(word), word))
    t.sort(reverse=True)
    res = []
    Dic = dict()
    for length, word in t:
        if length in Dic:
            Dic[length].append(word)
        else:
            Dic[length]=[word]
        random.shuffle(Dic[length])
    Keys = Dic.keys()
    Keys.sort(reverse=True)
    for a in Keys:
        res.extend(Dic[a])
    return res

sort_by_length(["The", "wonderful", "thing", "about", "tiggers","a","b"])
# Out:
# [(3, 'The'), (9, 'wonderful'), (5, 'thing'), (5, 'about'), (7, 'tiggers'), (1, 'a'), (1, 'b')]
# ['wonderful', 'tiggers', 'about', 'thing', 'The', 'a', 'b']

# %% [markdown]
# ### Exercise 4
#
# 1. Write a program that reads a word list from a file (see Section 9.1) and prints all the sets of
# words that are anagrams.
# Here is an example of what the output might look like:
#
#      ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled']
#      ['retainers', 'ternaries']
#      ['generating', 'greatening']
#      ['resmelts', 'smelters', 'termless']
#
# Hint: you might want to build a dictionary that maps from a set of letters to a list of words that can be spelled with those letters. The question is, how can you represent the set of letters in a way that can be used as a key?

# %%
import string

def process_line(line,dic):
    line = line.replace("-"," ")
    for word in line.split():
        words = word.strip(string.punctuation + string.whitespace)
        words = words.lower()
        wordlist = list(words)
        wordlistsort=sorted(wordlist)
        wordtuple = tuple(wordlistsort)
        if wordtuple in dic:
            if words in dic[wordtuple]:
                dic=dic
            else:
                dic [wordtuple].append(words)
        else:
            dic [wordtuple] = [words]
        
def process_file(filename):
    dic = dict()
    fil = open(filename)
    for line in fil:
        process_line(line,dic)
    dic = dict((k,v) for k,v in dic.items() if len(v) > 1)
    le=[]
    for a in dic:
        le.append((len(dic[a]),dic[a]))
    le.sort(reverse=True)
    for a,b in le:
        print b
    
    

process_file("emma.txt")
# Out:
# ['teased', 'seated', 'sedate']
# ['tea', 'eat', 'ate']
# ['stone', 'notes', 'tones']
# ['spot', 'stop', 'post']
# ['seat', 'eats', 'east']
# ['reads', 'dears', 'dares']
# ['read', 'dear', 'dare']
# ['miles', 'smile', 'limes']
# ['meal', 'male', 'lame']
# ['its', 'sit', 'tis']
# ['evils', 'lives', 'veils']
# ['despair', 'praised', 'aspired']
# ['alter', 'later', 'alert']
# ['yielded', 'deedily']
# ['xiv', 'xvi']
# ['wrong', 'grown']
# ['wives', 'views']
# ['who', 'how']
# ['what', 'thaw']
# ['wear', 'ware']
# ['was', 'saw']
# ['vessel', 'selves']
# ['tried', 'tired']
# ['tied', 'diet']
# ['thus', 'shut']
# ['throw', 'worth']
# ['three', 'there']
# ['things', 'nights']
# ["thing's", "night's"]
# ['thing', 'night']
# ['thin', 'hint']
# ['these', 'sheet']
# ['ten', 'net']
# ['tel', 'let']
# ['tears', 'stare']
# ['taste', 'state']
# ['tarts', 'start']
# ['takes', 'stake']
# ['suited', 'duties']
# ['sue', 'use']
# ['study', 'dusty']
# ['steady', 'stayed']
# ['stain', 'satin']
# ['stable', 'tables']
# ['spared', 'spread']
# ['sources', 'courses']
# ['smiled', 'misled']
# ['slighted', 'delights']
# ['slight', 'lights']
# ['sister', 'resist']
# ['sink', 'skin']
# ['single', 'genlis']
# ['sing', 'sign']
# ['silent', 'listen']
# ['side', 'dies']
# ['show', 'hows']
# ['share', 'hears']
# ['serve', 'verse']
# ['sept', 'step']
# ['sent', 'tens']
# ['send', 'ends']
# ['secure', 'rescue']
# ['said', 'aids']
# ['safer', 'fears']
# ['rude', 'rued']
# ['rout', 'tour']
# ['rose', 'sore']
# ['restoring', 'resorting']
# ['restored', 'resorted']
# ['residing', 'desiring']
# ['reserve', 'reverse']
# ['resent', 'enters']
# ['reigns', 'resign']
# ['readiest', 'steadier']
# ['reader', 'dearer']
# ['rate', 'tear']
# ['quite', 'quiet']
# ['preserve', 'perverse']
# ['please', 'asleep']
# ['player', 'parley']
# ['permission', 'impression']
# ['per', 'pre']
# ['parted', 'depart']
# ['pales', 'lapse']
# ['pale', 'plea']
# ['owns', 'snow']
# ['own', 'now']
# ['ours', 'sour']
# ['on', 'no']
# ['note', 'tone']
# ['needless', 'lessened']
# ['near', 'earn']
# ['name', 'mean']
# ['mile', 'lime']
# ['means', 'names']
# ['me', 'em']
# ['master', 'stream']
# ['married', 'admirer']
# ['maid', 'amid']
# ['lose', 'sole']
# ['lived', 'devil']
# ['license', 'silence']
# ['lest', 'lets']
# ['left', 'felt']
# ['least', 'stale']
# ['leading', 'dealing']
# ['lasting', 'salting']
# ['lasted', 'salted']
# ['last', 'salt']
# ['lament', 'mental']
# ['kramer', 'remark']
# ['keen', 'knee']
# ['ix', 'xi']
# ['iv', 'vi']
# ['indeed', 'denied']
# ['incessant', 'instances']
# ['ideas', 'aside']
# ['however', 'whoever']
# ['height', 'eighth']
# ['heart', 'earth']
# ['hate', 'heat']
# ['god', 'dog']
# ['gifted', 'fidget']
# ['general', 'enlarge']
# ['from', 'form']
# ['forest', 'softer']
# ['for', 'fro']
# ['files', 'flies']
# ['file', 'life']
# ['feared', 'deafer']
# ['fear', 'fare']
# ['expecting', 'excepting']
# ['expected', 'excepted']
# ['except', 'expect']
# ['evil', 'live']
# ['eltons', 'stolen']
# ['education', 'cautioned']
# ['earnest', 'nearest']
# ['dread', 'dared']
# ['doer', 'rode']
# ['disperse', 'presides']
# ['directions', 'discretion']
# ['dir', 'rid']
# ['desired', 'resided']
# ['design', 'signed']
# ['deserts', 'dessert']
# ['desert', 'rested']
# ['description', 'predictions']
# ['denial', 'nailed']
# ['delight', 'lighted']
# ['defer', 'freed']
# ['death', 'hated']
# ['deal', 'lead']
# ['dashed', 'shaded']
# ['dangers', 'gardens']
# ['danger', 'garden']
# ['credit', 'direct']
# ['course', 'source']
# ['could', 'cloud']
# ['continued', 'unnoticed']
# ['colds', 'scold']
# ['close', 'coles']
# ['cleared', 'declare']
# ['claimed', 'medical']
# ['charm', 'march']
# ['centre', 'recent']
# ['care', 'acre']
# ['bore', 'robe']
# ['boarder', 'broader']
# ['below', 'elbow']
# ['beings', 'begins']
# ['being', 'begin']
# ['bear', 'bare']
# ['backward', 'drawback']
# ['assume', 'amuses']
# ['artist', 'traits']
# ['article', 'recital']
# ['arise', 'raise']
# ['are', 'ear']
# ['apologies', 'apologise']
# ['any', 'nay']
# ['antagonist', 'stagnation']
# ['anger', 'range']
# ['ample', 'maple']
# ['amidst', 'admits']
# ['amiable', 'aimable']
# ['am', 'ma']
# ['altered', 'related']
# ['al', 'la']
# ['ah', 'ha']
# ['agrees', 'grease']
# ['agree', 'eager']

# %% [markdown]
# 2\. Modify the previous program so that it prints the largest set of anagrams first, followed by the second largest set, and so on.

# %%
import string

def process_line(line,dic):
    line = line.replace("-"," ")
    for word in line.split():
        words = word.strip(string.punctuation + string.whitespace)
        words = words.lower()
        wordlist = list(words)
        wordlistsort=sorted(wordlist)
        wordtuple = tuple(wordlistsort)
        if wordtuple in dic:
            if words in dic[wordtuple]:
                dic=dic
            else:
                dic [wordtuple].append(words)
        else:
            dic [wordtuple] = [words]
        
def process_file(filename):
    dic = dict()
    fil = open(filename)
    for line in fil:
        process_line(line,dic)
    dic = dict((k,v) for k,v in dic.items() if len(v) > 1)
    le=[]
    for a in dic:
        le.append((len(dic[a]),dic[a]))
    le.sort(reverse=True)
    for a,b in le:
        print b
    
    

process_file("words.txt")
# Out:
#   File "<ipython-input-2-a5cf565e6edd>", line 34
#     process_file("words.txt")
#                              ^
# IndentationError: expected an indented block

# %% [markdown]
# 3\. In Scrabble a “bingo” is when you play all seven tiles in your rack, along with a letter on the board, to form an eight-letter word. What set of 8 letters forms the most possible bingos? Hint: there are seven.

# %%
import string

def process_line(words,dic):
    wordlist = list(words)
    if len(wordlist) == 8:
        wordlistsort=sorted(wordlist)
        wordtuple = tuple(wordlistsort)
        if wordtuple in dic:
            dic[wordtuple] += 1
        else:
            dic[wordtuple] = 1


def process_file(filename):
    dic = dict()
    fil = open(filename)
    for word in fil:
        words = word.strip(string.punctuation + string.whitespace)
        process_line(words,dic)
    abc=[]
    for key in dic:
        abc.append((dic[key],key))
    abc.sort(reverse=True)
    return abc
    

process_file("words.txt")
# Out:
# [(7, ('a', 'e', 'g', 'i', 'n', 'r', 's', 't')),
#  (6, ('a', 'e', 'i', 'n', 'p', 'r', 's', 't')),
#  (6, ('a', 'e', 'g', 'i', 'l', 'n', 'r', 't')),
#  (6, ('a', 'e', 'g', 'i', 'l', 'n', 'r', 's')),
#  (6, ('a', 'e', 'e', 'g', 'n', 'r', 's', 't')),
#  (5, ('e', 'e', 'i', 'n', 'r', 'r', 's', 't')),
#  (5, ('d', 'e', 'i', 'o', 'p', 'r', 's', 't')),
#  (5, ('d', 'e', 'e', 'i', 'm', 'p', 'r', 's')),
#  (5, ('d', 'e', 'e', 'g', 'i', 'n', 'r', 's')),
#  (5, ('c', 'e', 'e', 'p', 'r', 's', 's', 't')),
#  (5, ('a', 'e', 'o', 'r', 'r', 's', 's', 't')),
#  (5, ('a', 'e', 'l', 'p', 'r', 's', 't', 't')),
#  (5, ('a', 'e', 'i', 'p', 'r', 's', 's', 't')),
#  (5, ('a', 'e', 'i', 'n', 'r', 'r', 's', 't')),
#  (5, ('a', 'e', 'i', 'l', 'n', 'r', 's', 't')),
#  (5, ('a', 'e', 'i', 'l', 'm', 'n', 's', 't')),
#  (5, ('a', 'e', 'e', 'l', 'm', 'n', 's', 's')),
#  (5, ('a', 'e', 'e', 'i', 'r', 's', 't', 't')),
#  (5, ('a', 'c', 'i', 'n', 'n', 'o', 's', 't')),
#  (5, ('a', 'c', 'e', 'i', 'n', 'r', 's', 't')),
#  (4, ('g', 'i', 'n', 'o', 'r', 's', 't', 'u')),
#  (4, ('e', 'i', 'o', 'p', 'r', 's', 's', 't')),
#  (4, ('e', 'i', 'i', 'l', 'n', 'o', 's', 's')),
#  (4, ('e', 'h', 'o', 'o', 'r', 's', 's', 't')),
#  (4, ('e', 'e', 'n', 'p', 'r', 's', 's', 't')),
#  (4, ('e', 'e', 'i', 'n', 'r', 's', 't', 't')),
#  (4, ('e', 'e', 'i', 'm', 'r', 'r', 's', 't')),
#  (4, ('e', 'e', 'i', 'm', 'p', 'r', 's', 's')),
#  (4, ('e', 'e', 'i', 'l', 'r', 'r', 's', 'v')),
#  (4, ('e', 'e', 'i', 'l', 'p', 'r', 's', 't')),
#  (4, ('e', 'e', 'i', 'l', 'n', 's', 's', 'v')),
#  (4, ('e', 'e', 'i', 'l', 'n', 'r', 's', 't')),
#  (4, ('e', 'e', 'g', 'i', 'n', 'r', 's', 't')),
#  (4, ('e', 'e', 'e', 'n', 'r', 'r', 's', 't')),
#  (4, ('d', 'e', 'e', 'n', 'r', 's', 't', 'u')),
#  (4, ('d', 'e', 'e', 'i', 'r', 's', 's', 't')),
#  (4, ('d', 'e', 'e', 'i', 'r', 'r', 's', 's')),
#  (4, ('d', 'e', 'e', 'i', 'l', 'r', 's', 'v')),
#  (4, ('c', 'n', 'o', 'o', 'r', 's', 't', 'u')),
#  (4, ('c', 'h', 'i', 'n', 'o', 'p', 't', 'y')),
#  (4, ('c', 'e', 'n', 'o', 'r', 's', 't', 'u')),
#  (4, ('c', 'e', 'i', 'k', 'l', 'r', 's', 't')),
#  (4, ('c', 'e', 'h', 'i', 'n', 'r', 's', 't')),
#  (4, ('c', 'e', 'h', 'i', 'i', 's', 't', 't')),
#  (4, ('c', 'e', 'f', 'i', 'n', 'o', 'r', 's')),
#  (4, ('c', 'e', 'e', 'l', 'o', 'r', 's', 't')),
#  (4, ('c', 'e', 'e', 'i', 'l', 'r', 's', 't')),
#  (4, ('c', 'd', 'e', 'e', 'n', 'o', 'r', 's')),
#  (4, ('a', 'e', 'n', 'o', 'r', 's', 's', 't')),
#  (4, ('a', 'e', 'l', 'p', 'r', 's', 's', 't')),
#  (4, ('a', 'e', 'i', 'n', 's', 's', 't', 't')),
#  (4, ('a', 'e', 'i', 'n', 'r', 's', 't', 'u')),
#  (4, ('a', 'e', 'i', 'n', 'r', 's', 't', 't')),
#  (4, ('a', 'e', 'i', 'n', 'r', 's', 's', 't')),
#  (4, ('a', 'e', 'i', 'l', 'n', 's', 's', 't')),
#  (4, ('a', 'e', 'i', 'l', 'm', 'r', 's', 't')),
#  (4, ('a', 'e', 'i', 'i', 'n', 's', 's', 't')),
#  (4, ('a', 'e', 'h', 'o', 'p', 's', 's', 't')),
#  (4, ('a', 'e', 'h', 'i', 'n', 's', 's', 't')),
#  (4, ('a', 'e', 'g', 'i', 'n', 'n', 'r', 's')),
#  (4, ('a', 'e', 'g', 'i', 'm', 'r', 's', 't')),
#  (4, ('a', 'e', 'g', 'i', 'm', 'n', 's', 't')),
#  (4, ('a', 'e', 'e', 'r', 'r', 's', 's', 't')),
#  (4, ('a', 'e', 'e', 'i', 'n', 'r', 's', 't')),
#  (4, ('a', 'e', 'e', 'i', 'l', 'r', 's', 't')),
#  (4, ('a', 'd', 'e', 'o', 'p', 'r', 'r', 't')),
#  (4, ('a', 'd', 'e', 'e', 'r', 'r', 's', 't')),
#  (4, ('a', 'd', 'e', 'e', 'p', 'r', 's', 't')),
#  (4, ('a', 'd', 'd', 'e', 'e', 'm', 'n', 'r')),
#  (4, ('a', 'd', 'd', 'e', 'e', 'g', 'n', 'r')),
#  (4, ('a', 'c', 'e', 'i', 'p', 'r', 's', 't')),
#  (4, ('a', 'c', 'e', 'i', 'n', 'n', 's', 't')),
#  (4, ('a', 'c', 'e', 'i', 'm', 'r', 's', 't')),
#  (4, ('a', 'c', 'e', 'g', 'i', 'n', 'r', 't')),
#  (4, ('a', 'c', 'e', 'e', 'r', 'r', 's', 't')),
#  (4, ('a', 'c', 'e', 'e', 'n', 'r', 's', 't')),
#  (4, ('a', 'c', 'e', 'e', 'i', 'n', 'r', 't')),
#  (4, ('a', 'c', 'e', 'e', 'h', 'r', 's', 't')),
#  (4, ('a', 'c', 'd', 'e', 'e', 'r', 'r', 't')),
#  (4, ('a', 'c', 'd', 'e', 'e', 'n', 'r', 't')),
#  (4, ('a', 'b', 'e', 'i', 'n', 'o', 'r', 't')),
#  (4, ('a', 'a', 'e', 'l', 'n', 'p', 'r', 't')),
#  (4, ('a', 'a', 'b', 'e', 'l', 'p', 'r', 's')),
#  (4, ('a', 'a', 'b', 'c', 'e', 'r', 's', 't')),
#  (3, ('m', 'o', 'o', 'o', 'r', 'r', 't', 'w')),
#  (3, ('i', 'n', 'o', 'o', 'p', 'r', 's', 't')),
#  (3, ('g', 'i', 'i', 'n', 'n', 'o', 'r', 's')),
#  (3, ('g', 'h', 'i', 'n', 'o', 'r', 't', 'w')),
#  (3, ('g', 'h', 'i', 'n', 'n', 'o', 'r', 't')),
#  (3, ('e', 'o', 'r', 'r', 's', 's', 't', 'u')),
#  (3, ('e', 'o', 'p', 'r', 's', 's', 't', 'u')),
#  (3, ('e', 'i', 'p', 'r', 'r', 's', 's', 'u')),
#  (3, ('e', 'i', 'o', 'r', 'r', 's', 's', 't')),
#  (3, ('e', 'i', 'o', 'p', 'r', 's', 'u', 'v')),
#  (3, ('e', 'i', 'n', 'p', 'r', 'r', 's', 't')),
#  (3, ('e', 'i', 'n', 'o', 'p', 'r', 's', 't')),
#  (3, ('e', 'i', 'n', 'o', 'o', 'p', 'r', 's')),
#  (3, ('e', 'i', 'm', 'o', 'r', 's', 's', 't')),
#  (3, ('e', 'i', 'm', 'o', 'p', 'r', 's', 's')),
#  (3, ('e', 'i', 'm', 'o', 'p', 'r', 'r', 's')),
#  (3, ('e', 'i', 'm', 'o', 'o', 'r', 's', 't')),
#  (3, ('e', 'i', 'm', 'n', 'r', 's', 't', 'u')),
#  (3, ('e', 'i', 'l', 'p', 'p', 'r', 's', 't')),
#  (3, ('e', 'i', 'k', 'r', 'r', 's', 's', 't')),
#  (3, ('e', 'i', 'i', 'p', 's', 's', 't', 't')),
#  (3, ('e', 'i', 'i', 'm', 'n', 'r', 's', 't')),
#  (3, ('e', 'h', 'l', 'r', 's', 's', 't', 'u')),
#  (3, ('e', 'h', 'i', 'o', 'r', 's', 's', 't')),
#  (3, ('e', 'h', 'i', 'l', 'o', 'p', 's', 't')),
#  (3, ('e', 'g', 'i', 'n', 'o', 'p', 'r', 's')),
#  (3, ('e', 'g', 'i', 'l', 'n', 'r', 's', 't')),
#  (3, ('e', 'g', 'i', 'i', 'm', 'n', 'r', 't')),
#  (3, ('e', 'g', 'i', 'i', 'l', 'n', 'o', 'r')),
#  (3, ('e', 'g', 'h', 'i', 'l', 'r', 's', 't')),
#  (3, ('e', 'f', 'i', 'm', 'n', 'o', 'r', 'r')),
#  (3, ('e', 'f', 'g', 'h', 'i', 'r', 's', 't')),
#  (3, ('e', 'e', 'o', 'r', 'r', 'r', 's', 't')),
#  (3, ('e', 'e', 'l', 'r', 's', 's', 't', 't')),
#  (3, ('e', 'e', 'l', 'm', 'r', 's', 's', 't')),
#  (3, ('e', 'e', 'l', 'l', 'p', 'r', 's', 's')),
#  (3, ('e', 'e', 'i', 'p', 'r', 'r', 's', 's')),
#  (3, ('e', 'e', 'i', 'n', 'r', 's', 't', 'v')),
#  (3, ('e', 'e', 'i', 'n', 'r', 's', 't', 'u')),
#  (3, ('e', 'e', 'i', 'l', 'o', 'r', 's', 'v')),
#  (3, ('e', 'e', 'h', 'i', 'o', 'r', 's', 't')),
#  (3, ('e', 'e', 'g', 'i', 'l', 'n', 's', 't')),
#  (3, ('e', 'e', 'g', 'i', 'l', 'n', 'p', 's')),
#  (3, ('e', 'e', 'g', 'h', 'i', 'n', 'r', 's')),
#  (3, ('e', 'e', 'f', 'o', 'r', 'r', 's', 't')),
#  (3, ('e', 'e', 'f', 'l', 'n', 'r', 's', 's')),
#  (3, ('e', 'e', 'f', 'i', 'i', 'r', 's', 't')),
#  (3, ('e', 'e', 'e', 'r', 'r', 'r', 's', 'v')),
#  (3, ('e', 'e', 'e', 'n', 'p', 'r', 's', 't')),
#  (3, ('e', 'e', 'e', 'i', 'm', 'p', 'r', 's')),
#  (3, ('e', 'e', 'e', 'i', 'l', 'r', 's', 't')),
#  (3, ('e', 'e', 'e', 'g', 'i', 'n', 'r', 's')),
#  (3, ('d', 'e', 'o', 'p', 'r', 's', 't', 'u')),
#  (3, ('d', 'e', 'n', 'o', 'r', 's', 't', 'u')),
#  (3, ('d', 'e', 'n', 'o', 'r', 's', 's', 'u')),
#  (3, ('d', 'e', 'l', 'o', 'o', 'r', 's', 's')),
#  (3, ('d', 'e', 'i', 'r', 's', 's', 't', 'u')),
#  (3, ('d', 'e', 'i', 'l', 'n', 's', 't', 'u')),
#  (3, ('d', 'e', 'i', 'l', 'n', 's', 's', 'w')),
#  (3, ('d', 'e', 'i', 'l', 'n', 'o', 's', 'u')),
#  (3, ('d', 'e', 'i', 'i', 'p', 'r', 's', 't')),
#  (3, ('d', 'e', 'i', 'i', 'n', 's', 't', 'u')),
#  (3, ('d', 'e', 'i', 'i', 'n', 'r', 's', 't')),
#  (3, ('d', 'e', 'i', 'i', 'n', 'o', 'r', 's')),
#  (3, ('d', 'e', 'h', 'n', 'o', 'r', 's', 'u')),
#  (3, ('d', 'e', 'g', 'i', 'i', 'n', 'r', 's')),
#  (3, ('d', 'e', 'g', 'g', 'i', 'l', 'n', 's')),
#  (3, ('d', 'e', 'e', 'n', 'o', 'r', 's', 'w')),
#  (3, ('d', 'e', 'e', 'l', 'r', 's', 't', 'u')),
#  (3, ('d', 'e', 'e', 'l', 'm', 'o', 'r', 's')),
#  (3, ('d', 'e', 'e', 'i', 'r', 's', 's', 'v')),
#  (3, ('d', 'e', 'e', 'i', 'r', 's', 's', 'u')),
#  (3, ('d', 'e', 'e', 'i', 'p', 'r', 's', 's')),
#  (3, ('d', 'e', 'e', 'i', 'p', 'r', 'r', 's')),
#  (3, ('d', 'e', 'e', 'i', 'n', 'r', 's', 't')),
#  (3, ('d', 'e', 'e', 'i', 'n', 'n', 'r', 't')),
#  (3, ('d', 'e', 'e', 'i', 'l', 'n', 's', 't')),
#  (3, ('d', 'e', 'e', 'h', 'i', 'l', 'r', 's')),
#  (3, ('d', 'e', 'e', 'g', 'i', 'l', 'n', 'r')),
#  (3, ('d', 'e', 'e', 'f', 'o', 'r', 's', 't')),
#  (3, ('d', 'e', 'e', 'f', 'l', 'o', 'r', 'w')),
#  (3, ('d', 'e', 'e', 'e', 'r', 'r', 's', 'v')),
#  (3, ('d', 'd', 'e', 'g', 'n', 'o', 'r', 'u')),
#  (3, ('c', 'i', 'i', 'l', 'o', 'p', 's', 't')),
#  (3, ('c', 'g', 'i', 'i', 'k', 'l', 'n', 's')),
#  (3, ('c', 'e', 'l', 'o', 'r', 's', 't', 'u')),
#  (3, ('c', 'e', 'l', 'o', 'r', 's', 's', 't')),
#  (3, ('c', 'e', 'l', 'n', 'o', 's', 's', 'u')),
#  (3, ('c', 'e', 'i', 'r', 's', 's', 't', 'u')),
#  (3, ('c', 'e', 'i', 'r', 'r', 's', 't', 't')),
#  (3, ('c', 'e', 'i', 'p', 'r', 's', 't', 'u')),
#  (3, ('c', 'e', 'i', 'l', 'o', 'r', 's', 't')),
#  (3, ('c', 'e', 'i', 'l', 'n', 's', 't', 'u')),
#  (3, ('c', 'e', 'i', 'l', 'n', 'o', 'o', 's')),
#  (3, ('c', 'e', 'i', 'l', 'm', 'o', 'p', 's')),
#  (3, ('c', 'e', 'i', 'k', 'o', 'r', 's', 't')),
#  (3, ('c', 'e', 'i', 'i', 'n', 'r', 's', 't')),
#  (3, ('c', 'e', 'i', 'i', 'm', 'r', 's', 't')),
#  (3, ('c', 'e', 'h', 'i', 'k', 's', 't', 't')),
#  (3, ('c', 'e', 'g', 'i', 'n', 'r', 's', 'u')),
#  (3, ('c', 'e', 'g', 'h', 'o', 'r', 's', 'u')),
#  (3, ('c', 'e', 'e', 'i', 'r', 's', 't', 'u')),
#  (3, ('c', 'e', 'e', 'i', 'p', 'r', 'r', 's')),
#  (3, ('c', 'e', 'e', 'i', 'l', 's', 's', 'v')),
#  (3, ('c', 'e', 'e', 'i', 'l', 'n', 'r', 's')),
#  (3, ('c', 'e', 'e', 'f', 'i', 'n', 'r', 't')),
#  (3, ('c', 'e', 'e', 'e', 'r', 'r', 's', 't')),
#  (3, ('c', 'd', 'i', 'n', 'o', 's', 't', 'u')),
#  (3, ('c', 'd', 'i', 'i', 'm', 'n', 'o', 'u')),
#  (3, ('c', 'd', 'g', 'i', 'l', 'n', 'o', 's')),
#  (3, ('c', 'd', 'e', 'e', 'o', 'r', 's', 't')),
#  (3, ('c', 'd', 'e', 'e', 'i', 'r', 's', 't')),
#  (3, ('c', 'd', 'e', 'e', 'i', 'p', 'r', 't')),
#  (3, ('c', 'd', 'e', 'e', 'i', 'o', 'r', 'v')),
#  (3, ('c', 'd', 'e', 'e', 'i', 'l', 'p', 's')),
#  (3, ('c', 'd', 'e', 'e', 'i', 'l', 'n', 's')),
#  (3, ('c', 'd', 'e', 'e', 'e', 'n', 'r', 't')),
#  (3, ('c', 'c', 'e', 'i', 'n', 'o', 'r', 's')),
#  (3, ('b', 'e', 'l', 'm', 'r', 's', 't', 'u')),
#  (3, ('b', 'e', 'i', 'm', 'r', 's', 't', 'u')),
#  (3, ('b', 'd', 'e', 'o', 'r', 's', 't', 'u')),
#  (3, ('b', 'd', 'e', 'n', 'o', 'r', 's', 'u')),
#  (3, ('a', 'i', 'o', 'p', 'r', 's', 's', 't')),
#  (3, ('a', 'i', 'm', 'n', 'o', 'p', 's', 't')),
#  (3, ('a', 'i', 'l', 'r', 's', 't', 't', 'u')),
#  (3, ('a', 'i', 'l', 'm', 'r', 's', 't', 'u')),
#  (3, ('a', 'i', 'i', 'l', 'n', 'p', 's', 't')),
#  (3, ('a', 'h', 'i', 'i', 'm', 'n', 's', 't')),
#  (3, ('a', 'g', 'i', 'n', 'o', 'r', 's', 's')),
#  (3, ('a', 'g', 'i', 'n', 'n', 't', 't', 'u')),
#  (3, ('a', 'g', 'i', 'l', 'n', 'p', 'r', 's')),
#  (3, ('a', 'g', 'i', 'l', 'l', 'n', 's', 'y')),
#  (3, ('a', 'g', 'h', 'i', 'n', 'p', 'r', 's')),
#  (3, ('a', 'g', 'h', 'i', 'l', 'n', 's', 'u')),
#  (3, ('a', 'g', 'h', 'i', 'l', 'n', 's', 's')),
#  (3, ('a', 'e', 'o', 'r', 's', 't', 'u', 'w')),
#  (3, ('a', 'e', 'o', 'p', 'r', 's', 's', 't')),
#  (3, ('a', 'e', 'n', 'p', 'r', 's', 't', 't')),
#  (3, ('a', 'e', 'm', 'r', 's', 's', 't', 't')),
#  (3, ('a', 'e', 'l', 'r', 's', 's', 't', 'w')),
#  (3, ('a', 'e', 'l', 'p', 'r', 's', 't', 'y')),
#  (3, ('a', 'e', 'k', 'o', 's', 't', 't', 'u')),
#  (3, ('a', 'e', 'i', 'r', 's', 't', 't', 't')),
#  (3, ('a', 'e', 'i', 'r', 's', 's', 't', 'w')),
#  (3, ('a', 'e', 'i', 'o', 'r', 's', 't', 'v')),
#  (3, ('a', 'e', 'i', 'm', 'r', 's', 's', 't')),
#  (3, ('a', 'e', 'i', 'l', 'r', 's', 's', 't')),
#  (3, ('a', 'e', 'i', 'l', 'p', 'r', 's', 't')),
#  (3, ('a', 'e', 'i', 'l', 'n', 'r', 't', 'u')),
#  (3, ('a', 'e', 'i', 'l', 'n', 'p', 's', 't')),
#  (3, ('a', 'e', 'i', 'l', 'n', 'o', 's', 't')),
#  (3, ('a', 'e', 'i', 'l', 'm', 's', 't', 't')),
#  (3, ('a', 'e', 'i', 'l', 'm', 'p', 'r', 's')),
#  (3, ('a', 'e', 'i', 'l', 'm', 'n', 'r', 's')),
#  (3, ('a', 'e', 'i', 'k', 'l', 'r', 's', 't')),
#  (3, ('a', 'e', 'h', 'n', 'r', 's', 't', 'u')),
#  (3, ('a', 'e', 'h', 'n', 'o', 'p', 's', 't')),
#  (3, ('a', 'e', 'h', 'm', 'n', 'o', 'r', 's')),
#  (3, ('a', 'e', 'h', 'i', 'l', 'p', 'r', 's')),
#  (3, ('a', 'e', 'g', 'n', 'r', 'r', 's', 't')),
#  (3, ('a', 'e', 'g', 'm', 'n', 'o', 's', 't')),
#  (3, ('a', 'e', 'g', 'l', 'p', 'r', 's', 'u')),
#  (3, ('a', 'e', 'g', 'i', 'n', 's', 's', 't')),
#  (3, ('a', 'e', 'g', 'i', 'n', 'r', 't', 'v')),
#  (3, ('a', 'e', 'g', 'i', 'n', 'r', 's', 's')),
#  (3, ('a', 'e', 'g', 'i', 'l', 'o', 'r', 's')),
#  (3, ('a', 'e', 'g', 'i', 'l', 'n', 's', 't')),
#  (3, ('a', 'e', 'g', 'i', 'l', 'n', 's', 's')),
#  (3, ('a', 'e', 'g', 'i', 'l', 'n', 'r', 'y')),
#  (3, ('a', 'e', 'g', 'i', 'l', 'm', 'n', 't')),
#  (3, ('a', 'e', 'g', 'i', 'l', 'm', 'n', 'r')),
#  (3, ('a', 'e', 'g', 'h', 'i', 'n', 'r', 't')),
#  (3, ('a', 'e', 'g', 'h', 'i', 'n', 'r', 's')),
#  (3, ('a', 'e', 'g', 'g', 'i', 'n', 'r', 's')),
#  (3, ('a', 'e', 'g', 'g', 'i', 'l', 'n', 'r')),
#  (3, ('a', 'e', 'f', 'l', 'o', 'r', 's', 't')),
#  (3, ('a', 'e', 'e', 'r', 's', 's', 't', 't')),
#  (3, ('a', 'e', 'e', 'p', 'p', 'r', 'r', 's')),
#  (3, ('a', 'e', 'e', 'n', 'r', 's', 's', 't')),
#  (3, ('a', 'e', 'e', 'n', 'n', 'r', 's', 's')),
#  (3, ('a', 'e', 'e', 'm', 'r', 's', 's', 't')),
#  (3, ('a', 'e', 'e', 'l', 'r', 'r', 's', 'v')),
#  (3, ('a', 'e', 'e', 'l', 'r', 'r', 's', 't')),
#  (3, ('a', 'e', 'e', 'l', 'p', 'r', 's', 't')),
#  (3, ('a', 'e', 'e', 'l', 'm', 's', 's', 't')),
#  (3, ('a', 'e', 'e', 'l', 'm', 'n', 'p', 's')),
#  (3, ('a', 'e', 'e', 'i', 'r', 's', 't', 'w')),
#  (3, ('a', 'e', 'e', 'i', 'n', 's', 't', 't')),
#  (3, ('a', 'e', 'e', 'i', 'm', 's', 't', 't')),
#  (3, ('a', 'e', 'e', 'i', 'l', 's', 't', 'v')),
#  (3, ('a', 'e', 'e', 'i', 'l', 'n', 'r', 't')),
#  (3, ('a', 'e', 'e', 'h', 'r', 's', 't', 't')),
#  (3, ('a', 'e', 'e', 'g', 'l', 'r', 's', 's')),
#  (3, ('a', 'e', 'e', 'g', 'l', 'n', 'r', 's')),
#  (3, ('a', 'e', 'e', 'g', 'i', 'l', 'n', 't')),
#  (3, ('a', 'e', 'e', 'f', 'n', 'r', 's', 't')),
#  (3, ('a', 'e', 'e', 'f', 'i', 'l', 's', 't')),
#  (3, ('a', 'e', 'e', 'e', 'g', 'r', 's', 't')),
#  (3, ('a', 'e', 'e', 'e', 'g', 'l', 'r', 't')),
#  (3, ('a', 'd', 'n', 'o', 'o', 'r', 's', 't')),
#  (3, ('a', 'd', 'i', 'l', 'o', 'r', 't', 'y')),
#  (3, ('a', 'd', 'e', 'p', 'r', 's', 't', 'u')),
#  (3, ('a', 'd', 'e', 'o', 'r', 's', 't', 'u')),
#  (3, ('a', 'd', 'e', 'o', 'p', 'r', 's', 't')),
#  (3, ('a', 'd', 'e', 'n', 'r', 's', 't', 'u')),
#  (3, ('a', 'd', 'e', 'n', 'o', 'p', 'r', 's')),
#  (3, ('a', 'd', 'e', 'm', 'n', 'r', 's', 'u')),
#  (3, ('a', 'd', 'e', 'l', 'o', 'r', 's', 't')),
#  (3, ('a', 'd', 'e', 'l', 'n', 'p', 'r', 'u')),
#  (3, ('a', 'd', 'e', 'i', 'r', 's', 's', 't')),
#  (3, ('a', 'd', 'e', 'i', 'n', 'r', 't', 'u')),
#  (3, ('a', 'd', 'e', 'i', 'n', 'r', 's', 'u')),
#  (3, ('a', 'd', 'e', 'i', 'n', 'o', 'r', 't')),
#  (3, ('a', 'd', 'e', 'i', 'm', 'r', 'r', 's')),
#  (3, ('a', 'd', 'e', 'i', 'l', 'o', 's', 't')),
#  (3, ('a', 'd', 'e', 'h', 'i', 'n', 'p', 's')),
#  (3, ('a', 'd', 'e', 'g', 'i', 'n', 'r', 't')),
#  (3, ('a', 'd', 'e', 'g', 'i', 'n', 'r', 's')),
#  (3, ('a', 'd', 'e', 'g', 'i', 'm', 'n', 'r')),
#  (3, ('a', 'd', 'e', 'g', 'i', 'l', 'n', 's')),
#  (3, ('a', 'd', 'e', 'e', 'r', 'r', 'r', 'w')),
#  (3, ('a', 'd', 'e', 'e', 'n', 's', 's', 't')),
#  (3, ('a', 'd', 'e', 'e', 'n', 'r', 't', 'u')),
#  (3, ('a', 'd', 'e', 'e', 'n', 'r', 't', 't')),
#  (3, ('a', 'd', 'e', 'e', 'n', 'r', 's', 'u')),
#  (3, ('a', 'd', 'e', 'e', 'i', 'r', 's', 't')),
#  (3, ('a', 'd', 'e', 'e', 'i', 'l', 'r', 't')),
#  (3, ('a', 'd', 'e', 'e', 'i', 'l', 'r', 's')),
#  (3, ('a', 'd', 'e', 'e', 'i', 'l', 'n', 't')),
#  (3, ('a', 'd', 'e', 'e', 'h', 'k', 'n', 'r')),
#  (3, ('a', 'd', 'e', 'e', 'g', 'n', 'r', 's')),
#  (3, ('a', 'd', 'e', 'e', 'e', 'f', 'r', 't')),
#  (3, ('a', 'd', 'd', 'e', 'e', 'g', 'r', 'r')),
#  (3, ('a', 'c', 'h', 'i', 'o', 'r', 's', 't')),
#  (3, ('a', 'c', 'g', 'i', 'n', 'p', 'r', 's')),
#  (3, ('a', 'c', 'g', 'i', 'n', 'o', 's', 't')),
#  (3, ('a', 'c', 'g', 'h', 'i', 'n', 'r', 's')),
#  (3, ('a', 'c', 'e', 'n', 'r', 's', 't', 'u')),
#  (3, ('a', 'c', 'e', 'l', 'p', 'r', 's', 's')),
#  (3, ('a', 'c', 'e', 'l', 'o', 's', 't', 'u')),
#  (3, ('a', 'c', 'e', 'l', 'o', 'r', 's', 's')),
#  (3, ('a', 'c', 'e', 'i', 'r', 's', 't', 't')),
#  (3, ('a', 'c', 'e', 'i', 'n', 's', 't', 't')),
#  (3, ('a', 'c', 'e', 'i', 'n', 'o', 's', 't')),
#  (3, ('a', 'c', 'e', 'i', 'n', 'o', 'r', 't')),
#  (3, ('a', 'c', 'e', 'i', 'n', 'o', 'p', 'r')),
#  (3, ('a', 'c', 'e', 'i', 'l', 'r', 's', 'v')),
#  (3, ('a', 'c', 'e', 'i', 'l', 'r', 's', 't')),
#  (3, ('a', 'c', 'e', 'i', 'l', 'p', 'r', 's')),
#  (3, ('a', 'c', 'e', 'i', 'l', 'n', 'p', 's')),
#  (3, ('a', 'c', 'e', 'i', 'l', 'm', 'r', 's')),
#  (3, ('a', 'c', 'e', 'h', 'n', 's', 's', 't')),
#  (3, ('a', 'c', 'e', 'h', 'n', 'r', 's', 't')),
#  (3, ('a', 'c', 'e', 'h', 'l', 'o', 'r', 't')),
#  (3, ('a', 'c', 'e', 'h', 'i', 'p', 's', 't')),
#  (3, ('a', 'c', 'e', 'h', 'i', 'p', 'r', 't')),
#  (3, ('a', 'c', 'e', 'h', 'i', 'm', 's', 't')),
#  (3, ('a', 'c', 'e', 'g', 'i', 'r', 's', 't')),
#  (3, ('a', 'c', 'e', 'g', 'i', 'm', 'n', 'r')),
#  (3, ('a', 'c', 'e', 'e', 'm', 'r', 'r', 's')),
#  (3, ('a', 'c', 'e', 'e', 'l', 'n', 'r', 's')),
#  (3, ('a', 'c', 'e', 'e', 'h', 'r', 'r', 's')),
#  (3, ('a', 'c', 'e', 'e', 'h', 'm', 'r', 's')),
#  (3, ('a', 'c', 'd', 'i', 'i', 'r', 's', 't')),
#  (3, ('a', 'c', 'd', 'e', 'o', 'r', 't', 'u')),
#  (3, ('a', 'c', 'd', 'e', 'n', 'r', 't', 'u')),
#  (3, ('a', 'c', 'd', 'e', 'i', 'r', 't', 't')),
#  (3, ('a', 'c', 'd', 'e', 'i', 'm', 'n', 'o')),
#  (3, ('a', 'c', 'd', 'e', 'i', 'l', 'r', 's')),
#  (3, ('a', 'c', 'd', 'e', 'i', 'l', 'm', 's')),
#  (3, ('a', 'c', 'd', 'e', 'i', 'i', 'n', 't')),
#  (3, ('a', 'c', 'c', 'e', 'k', 'l', 'r', 's')),
#  (3, ('a', 'b', 'i', 'l', 'n', 'o', 'o', 't')),
#  (3, ('a', 'b', 'e', 'l', 'r', 's', 't', 't')),
#  (3, ('a', 'b', 'e', 'l', 'o', 's', 't', 'w')),
#  (3, ('a', 'b', 'e', 'l', 'o', 'r', 's', 't')),
#  (3, ('a', 'b', 'e', 'i', 'n', 'o', 's', 't')),
#  (3, ('a', 'b', 'e', 'i', 'l', 's', 's', 't')),
#  (3, ('a', 'b', 'e', 'i', 'l', 'm', 's', 't')),
#  (3, ('a', 'b', 'e', 'g', 'i', 'n', 'r', 't')),
#  (3, ('a', 'b', 'c', 'e', 'h', 'm', 'r', 's')),
#  (3, ('a', 'b', 'b', 'b', 'e', 'l', 'r', 's')),
#  (3, ('a', 'a', 'i', 'm', 'n', 's', 's', 't')),
#  (3, ('a', 'a', 'e', 'i', 'p', 'r', 's', 't')),
#  (3, ('a', 'a', 'e', 'i', 'n', 'r', 's', 't')),
#  (3, ('a', 'a', 'e', 'i', 'l', 'r', 's', 's')),
#  (3, ('a', 'a', 'e', 'g', 'l', 'l', 's', 't')),
#  (3, ('a', 'a', 'e', 'g', 'i', 'n', 'r', 's')),
#  (3, ('a', 'a', 'c', 'e', 'l', 'n', 't', 'u')),
#  (3, ('a', 'a', 'c', 'e', 'i', 'n', 'r', 's')),
#  (3, ('a', 'a', 'c', 'e', 'i', 'l', 'l', 'n')),
#  (3, ('a', 'a', 'c', 'd', 'g', 'i', 'n', 'r')),
#  (3, ('a', 'a', 'c', 'c', 'o', 's', 't', 't')),
#  (3, ('a', 'a', 'c', 'c', 'l', 'r', 's', 'u')),
#  (3, ('a', 'a', 'b', 'e', 'l', 's', 't', 't')),
#  (3, ('a', 'a', 'b', 'e', 'e', 'l', 'l', 's')),
#  (3, ('a', 'a', 'a', 'n', 'r', 's', 't', 't')),
#  (2, ('n', 'o', 'r', 's', 't', 't', 'u', 'u')),
#  (2, ('n', 'n', 'o', 'o', 'o', 'p', 's', 't')),
#  (2, ('l', 'l', 'o', 'p', 's', 't', 'u', 'u')),
#  (2, ('l', 'l', 'o', 'o', 'r', 's', 't', 'u')),
#  (2, ('k', 'o', 'o', 'r', 's', 't', 'u', 'w')),
#  (2, ('k', 'l', 'o', 'o', 'o', 's', 't', 'u')),
#  (2, ('i', 'o', 'o', 'p', 'r', 's', 't', 'y')),
#  (2, ('i', 'n', 'n', 'o', 'o', 'p', 's', 's')),
#  (2, ('i', 'm', 'n', 'o', 'o', 'r', 't', 'y')),
#  (2, ('i', 'l', 'o', 'o', 'p', 's', 's', 't')),
#  (2, ('i', 'l', 'n', 'o', 'p', 's', 's', 'u')),
#  (2, ('i', 'l', 'n', 'o', 'o', 'p', 's', 'y')),
#  (2, ('i', 'j', 'j', 's', 's', 't', 'u', 'u')),
#  (2, ('i', 'i', 'm', 'n', 'p', 'r', 's', 't')),
#  (2, ('i', 'i', 'm', 'n', 'n', 'o', 's', 'u')),
#  (2, ('h', 'p', 'r', 's', 't', 't', 'u', 'u')),
#  (2, ('h', 'i', 'm', 'o', 'r', 's', 't', 'u')),
#  (2, ('h', 'i', 'l', 'n', 'o', 's', 't', 'y')),
#  (2, ('h', 'i', 'i', 'l', 'l', 'm', 'm', 'o')),
#  (2, ('g', 'l', 'o', 'o', 'p', 't', 'y', 'y')),
#  (2, ('g', 'l', 'n', 'o', 'r', 's', 't', 'y')),
#  (2, ('g', 'l', 'm', 'n', 'o', 'o', 'o', 'y')),
#  (2, ('g', 'i', 'n', 'p', 'r', 's', 'u', 'u')),
#  (2, ('g', 'i', 'n', 'o', 'r', 's', 't', 'y')),
#  (2, ('g', 'i', 'n', 'o', 'r', 's', 't', 'w')),
#  (2, ('g', 'i', 'n', 'o', 'p', 's', 's', 't')),
#  (2, ('g', 'i', 'n', 'o', 'p', 'p', 's', 't')),
#  (2, ('g', 'i', 'n', 'o', 'o', 'p', 'p', 's')),
#  (2, ('g', 'i', 'n', 'n', 'r', 's', 't', 'u')),
#  (2, ('g', 'i', 'n', 'n', 'o', 'o', 'p', 's')),
#  (2, ('g', 'i', 'l', 'n', 'r', 's', 't', 'u')),
#  (2, ('g', 'i', 'l', 'n', 'o', 'p', 's', 'y')),
#  (2, ('g', 'i', 'l', 'n', 'o', 'p', 'p', 'p')),
#  (2, ('g', 'i', 'l', 'n', 'o', 'o', 's', 't')),
#  (2, ('g', 'i', 'k', 'l', 'n', 'n', 'r', 'u')),
#  (2, ('g', 'i', 'i', 'n', 's', 't', 't', 'w')),
#  (2, ('g', 'i', 'i', 'n', 's', 's', 't', 'u')),
#  (2, ('g', 'i', 'i', 'n', 'p', 's', 't', 't')),
#  (2, ('g', 'i', 'i', 'n', 'p', 'r', 's', 't')),
#  (2, ('g', 'i', 'i', 'n', 'o', 'p', 's', 't')),
#  (2, ('g', 'i', 'i', 'n', 'n', 's', 't', 't')),
#  (2, ('g', 'i', 'i', 'm', 'n', 'o', 't', 'v')),
#  (2, ('g', 'i', 'i', 'm', 'n', 'n', 't', 'u')),
#  (2, ('g', 'i', 'i', 'l', 'n', 's', 't', 't')),
#  (2, ('g', 'i', 'i', 'l', 'n', 'p', 'p', 's')),
#  (2, ('g', 'i', 'i', 'k', 'n', 'r', 's', 't')),
#  (2, ('g', 'i', 'i', 'k', 'n', 'n', 'p', 's')),
#  (2, ('g', 'i', 'i', 'k', 'l', 'n', 's', 't')),
#  (2, ('g', 'i', 'i', 'k', 'l', 'n', 'n', 's')),
#  (2, ('g', 'i', 'i', 'k', 'l', 'l', 'n', 's')),
#  (2, ('g', 'i', 'i', 'j', 'n', 'o', 's', 't')),
#  (2, ('g', 'h', 'n', 'o', 's', 's', 't', 'u')),
#  (2, ('g', 'h', 'i', 'n', 's', 's', 't', 'u')),
#  (2, ('g', 'h', 'i', 'n', 'o', 's', 't', 'u')),
#  (2, ('g', 'h', 'i', 'n', 'o', 's', 't', 't')),
#  (2, ('g', 'h', 'i', 'n', 'o', 'o', 's', 't')),
#  (2, ('g', 'h', 'i', 'n', 'n', 's', 't', 'u')),
#  (2, ('g', 'h', 'i', 'l', 'n', 's', 't', 'u')),
#  (2, ('g', 'h', 'i', 'i', 'n', 's', 't', 'w')),
#  (2, ('g', 'h', 'i', 'i', 'n', 's', 't', 't')),
#  (2, ('g', 'g', 'i', 'l', 'n', 't', 't', 'u')),
#  (2, ('g', 'g', 'i', 'l', 'n', 'o', 's', 's')),
#  (2, ('g', 'g', 'i', 'i', 'n', 'n', 'o', 'r')),
#  (2, ('g', 'g', 'i', 'i', 'l', 'n', 'n', 't')),
#  (2, ('g', 'g', 'i', 'i', 'l', 'n', 'n', 's')),
#  (2, ('g', 'g', 'h', 'i', 'i', 'n', 'r', 't')),
#  (2, ('g', 'g', 'g', 'i', 'l', 'n', 'o', 's')),
#  (2, ('g', 'g', 'g', 'i', 'i', 'n', 's', 'w')),
#  (2, ('f', 'i', 'l', 'l', 'n', 's', 'u', 'y')),
#  (2, ('f', 'i', 'k', 'k', 'l', 'n', 'o', 's')),
#  (2, ('f', 'h', 'l', 'o', 'r', 't', 'u', 'w')),
#  (2, ('f', 'g', 'i', 'i', 'l', 'n', 'r', 't')),
#  (2, ('f', 'g', 'h', 'i', 'l', 'n', 's', 'u')),
#  (2, ('f', 'f', 'k', 'l', 'o', 'r', 's', 'u')),
#  (2, ('e', 'p', 'r', 'r', 's', 's', 'u', 'u')),
#  (2, ('e', 'o', 'r', 's', 's', 't', 't', 'u')),
#  (2, ('e', 'o', 'r', 'r', 's', 's', 't', 'y')),
#  (2, ('e', 'o', 'p', 'r', 's', 's', 't', 't')),
#  (2, ('e', 'o', 'p', 'r', 'r', 's', 't', 'u')),
#  (2, ('e', 'o', 'p', 'r', 'r', 's', 's', 't')),
#  (2, ('e', 'o', 'p', 'p', 'r', 's', 's', 'u')),
#  (2, ('e', 'o', 'o', 'r', 't', 't', 'u', 'w')),
#  (2, ('e', 'o', 'o', 'p', 'r', 's', 't', 'v')),
#  (2, ('e', 'o', 'o', 'p', 'p', 'r', 's', 's')),
#  (2, ('e', 'n', 'p', 'r', 'r', 's', 's', 'u')),
#  (2, ('e', 'n', 'o', 'r', 'r', 't', 'u', 'v')),
#  (2, ('e', 'n', 'o', 'r', 'r', 's', 'u', 'v')),
#  (2, ('e', 'n', 'o', 'o', 'p', 's', 't', 't')),
#  (2, ('e', 'n', 'o', 'o', 'p', 'r', 's', 's')),
#  (2, ('e', 'n', 'n', 'o', 's', 's', 't', 'u')),
#  (2, ('e', 'm', 'p', 'r', 's', 't', 't', 'u')),
#  (2, ('e', 'm', 'p', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'm', 'o', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'm', 'n', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'm', 'n', 'o', 'r', 's', 't', 'u')),
#  (2, ('e', 'm', 'n', 'o', 'o', 'r', 's', 't')),
#  (2, ('e', 'm', 'm', 'n', 'o', 'r', 's', 'u')),
#  (2, ('e', 'l', 'o', 'r', 's', 't', 'u', 'y')),
#  (2, ('e', 'l', 'o', 'p', 's', 't', 't', 'u')),
#  (2, ('e', 'l', 'o', 'p', 'r', 's', 't', 'y')),
#  (2, ('e', 'l', 'o', 'o', 'r', 's', 't', 't')),
#  (2, ('e', 'l', 'n', 'o', 's', 's', 's', 'w')),
#  (2, ('e', 'l', 'l', 'o', 's', 's', 't', 'u')),
#  (2, ('e', 'l', 'l', 'o', 'r', 'r', 's', 't')),
#  (2, ('e', 'l', 'l', 'o', 'p', 's', 't', 'u')),
#  (2, ('e', 'i', 'r', 's', 's', 't', 'u', 'v')),
#  (2, ('e', 'i', 'r', 's', 's', 't', 't', 'w')),
#  (2, ('e', 'i', 'r', 's', 's', 't', 't', 'u')),
#  (2, ('e', 'i', 'p', 'r', 's', 's', 't', 't')),
#  (2, ('e', 'i', 'p', 'p', 'r', 'r', 's', 't')),
#  (2, ('e', 'i', 'o', 'r', 's', 't', 'u', 'v')),
#  (2, ('e', 'i', 'o', 'r', 'r', 's', 't', 'v')),
#  (2, ('e', 'i', 'o', 'p', 'r', 's', 't', 'v')),
#  (2, ('e', 'i', 'o', 'p', 'r', 'r', 's', 't')),
#  (2, ('e', 'i', 'o', 'o', 's', 's', 't', 't')),
#  (2, ('e', 'i', 'o', 'o', 'r', 's', 't', 't')),
#  (2, ('e', 'i', 'n', 'q', 's', 't', 'u', 'u')),
#  (2, ('e', 'i', 'n', 'o', 's', 's', 's', 't')),
#  (2, ('e', 'i', 'n', 'o', 'r', 's', 't', 'u')),
#  (2, ('e', 'i', 'n', 'o', 'r', 's', 't', 't')),
#  (2, ('e', 'i', 'n', 'o', 'r', 's', 's', 'u')),
#  (2, ('e', 'i', 'n', 'o', 'o', 's', 's', 'z')),
#  (2, ('e', 'i', 'n', 'n', 'o', 's', 't', 't')),
#  (2, ('e', 'i', 'n', 'n', 'o', 'r', 's', 't')),
#  (2, ('e', 'i', 'm', 'r', 's', 's', 's', 'u')),
#  (2, ('e', 'i', 'm', 'p', 'r', 's', 't', 'u')),
#  (2, ('e', 'i', 'm', 'o', 's', 't', 't', 'u')),
#  (2, ('e', 'i', 'm', 'o', 'r', 's', 't', 'w')),
#  (2, ('e', 'i', 'm', 'o', 'r', 'r', 's', 't')),
#  (2, ('e', 'i', 'm', 'o', 'p', 'r', 'r', 't')),
#  (2, ('e', 'i', 'm', 'n', 'r', 's', 's', 't')),
#  (2, ('e', 'i', 'm', 'n', 'o', 's', 's', 't')),
#  (2, ('e', 'i', 'm', 'n', 'o', 'p', 's', 't')),
#  (2, ('e', 'i', 'm', 'n', 'o', 'o', 's', 't')),
#  (2, ('e', 'i', 'm', 'n', 'o', 'o', 'r', 't')),
#  (2, ('e', 'i', 'm', 'n', 'o', 'o', 'r', 's')),
#  (2, ('e', 'i', 'l', 'r', 's', 's', 't', 'y')),
#  (2, ('e', 'i', 'l', 'p', 'r', 's', 't', 't')),
#  (2, ('e', 'i', 'l', 'o', 'p', 's', 't', 't')),
#  (2, ('e', 'i', 'l', 'o', 'p', 'r', 's', 'v')),
#  (2, ('e', 'i', 'l', 'o', 'o', 's', 's', 't')),
#  (2, ('e', 'i', 'l', 'n', 'p', 's', 's', 'u')),
#  (2, ('e', 'i', 'l', 'n', 'o', 's', 't', 'u')),
#  (2, ('e', 'i', 'l', 'n', 'o', 'o', 's', 't')),
#  (2, ('e', 'i', 'l', 'm', 'p', 's', 't', 'u')),
#  (2, ('e', 'i', 'l', 'm', 'p', 's', 's', 't')),
#  (2, ('e', 'i', 'l', 'm', 'o', 'p', 's', 't')),
#  (2, ('e', 'i', 'l', 'm', 'n', 't', 'u', 'y')),
#  (2, ('e', 'i', 'l', 'm', 'n', 'p', 's', 's')),
#  (2, ('e', 'i', 'l', 'm', 'n', 'o', 'o', 's')),
#  (2, ('e', 'i', 'l', 'l', 's', 's', 's', 't')),
#  (2, ('e', 'i', 'l', 'l', 'n', 's', 't', 'y')),
#  (2, ('e', 'i', 'k', 'n', 'r', 's', 't', 't')),
#  (2, ('e', 'i', 'k', 'n', 'n', 'o', 'r', 's')),
#  (2, ('e', 'i', 'k', 'l', 'n', 'p', 'r', 's')),
#  (2, ('e', 'i', 'i', 'r', 's', 's', 't', 'v')),
#  (2, ('e', 'i', 'i', 'n', 'r', 's', 't', 'v')),
#  (2, ('e', 'i', 'i', 'n', 'r', 's', 's', 't')),
#  (2, ('e', 'i', 'i', 'n', 'q', 't', 'u', 'y')),
#  (2, ('e', 'i', 'i', 'n', 'o', 's', 's', 't')),
#  (2, ('e', 'i', 'i', 'm', 's', 's', 't', 't')),
#  (2, ('e', 'i', 'i', 'm', 'n', 'o', 's', 's')),
#  (2, ('e', 'i', 'i', 'l', 's', 's', 't', 't')),
#  (2, ('e', 'i', 'i', 'l', 'o', 'p', 's', 't')),
#  (2, ('e', 'i', 'i', 'l', 'n', 's', 't', 't')),
#  (2, ('e', 'i', 'i', 'l', 'm', 's', 't', 't')),
#  (2, ('e', 'i', 'i', 'l', 'm', 's', 's', 't')),
#  (2, ('e', 'h', 'o', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'h', 'o', 'p', 'r', 's', 's', 't')),
#  (2, ('e', 'h', 'o', 'o', 'p', 's', 't', 'u')),
#  (2, ('e', 'h', 'n', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'h', 'n', 'o', 'r', 's', 's', 'u')),
#  (2, ('e', 'h', 'm', 'o', 'o', 'r', 's', 't')),
#  (2, ('e', 'h', 'm', 'n', 'o', 'o', 'r', 's')),
#  (2, ('e', 'h', 'l', 'o', 'r', 's', 's', 't')),
#  (2, ('e', 'h', 'l', 'o', 'o', 'p', 's', 't')),
#  (2, ('e', 'h', 'i', 'o', 'r', 's', 't', 't')),
#  (2, ('e', 'h', 'i', 'n', 'o', 'r', 's', 't')),
#  (2, ('e', 'h', 'i', 'm', 'n', 'r', 's', 'u')),
#  (2, ('e', 'h', 'i', 'm', 'n', 'o', 's', 's')),
#  (2, ('e', 'h', 'i', 'l', 'p', 'r', 's', 't')),
#  (2, ('e', 'h', 'i', 'l', 'o', 'p', 'r', 's')),
#  (2, ('e', 'h', 'i', 'l', 'n', 'o', 's', 't')),
#  (2, ('e', 'h', 'i', 'k', 'n', 'r', 's', 't')),
#  (2, ('e', 'g', 'o', 'p', 'r', 'r', 's', 'u')),
#  (2, ('e', 'g', 'n', 'r', 'r', 's', 't', 'u')),
#  (2, ('e', 'g', 'm', 'm', 'r', 's', 't', 'u')),
#  (2, ('e', 'g', 'i', 's', 's', 't', 't', 'u')),
#  (2, ('e', 'g', 'i', 'o', 'r', 's', 's', 't')),
#  (2, ('e', 'g', 'i', 'o', 'p', 'r', 's', 'u')),
#  (2, ('e', 'g', 'i', 'n', 'r', 's', 't', 'w')),
#  (2, ('e', 'g', 'i', 'n', 'r', 's', 's', 't')),
#  (2, ('e', 'g', 'i', 'n', 'r', 'r', 's', 't')),
#  (2, ('e', 'g', 'i', 'n', 'p', 'r', 't', 'u')),
#  (2, ('e', 'g', 'i', 'n', 'p', 'r', 's', 'u')),
#  (2, ('e', 'g', 'i', 'n', 'p', 'r', 's', 's')),
#  (2, ('e', 'g', 'i', 'n', 'p', 'r', 'r', 's')),
#  (2, ('e', 'g', 'i', 'm', 'n', 'p', 's', 't')),
#  (2, ('e', 'g', 'i', 'm', 'm', 's', 't', 'u')),
#  (2, ('e', 'g', 'i', 'l', 'r', 's', 's', 't')),
#  (2, ('e', 'g', 'i', 'l', 'n', 's', 's', 'w')),
#  (2, ('e', 'g', 'i', 'l', 'n', 's', 's', 't')),
#  (2, ('e', 'g', 'i', 'l', 'n', 'o', 'r', 'w')),
#  (2, ('e', 'g', 'i', 'l', 'm', 'o', 'o', 'r')),
#  (2, ('e', 'g', 'i', 'l', 'm', 'n', 'r', 's')),
#  (2, ('e', 'g', 'i', 'i', 'n', 'r', 's', 't')),
#  (2, ('e', 'g', 'i', 'i', 'n', 'p', 'r', 's')),
#  (2, ('e', 'g', 'i', 'i', 'n', 'n', 'p', 'r')),
#  (2, ('e', 'g', 'i', 'i', 'l', 'n', 's', 't')),
#  (2, ('e', 'g', 'i', 'i', 'l', 'n', 'r', 'v')),
#  (2, ('e', 'g', 'i', 'i', 'l', 'n', 'p', 's')),
#  (2, ('e', 'g', 'i', 'i', 'l', 'n', 'n', 's')),
#  (2, ('e', 'g', 'i', 'i', 'k', 'l', 'n', 'r')),
#  (2, ('e', 'g', 'h', 'o', 'r', 's', 't', 'u')),
#  (2, ('e', 'g', 'h', 'l', 'o', 'o', 't', 'y')),
#  (2, ('e', 'g', 'h', 'i', 'i', 'r', 's', 't')),
#  (2, ('e', 'g', 'h', 'i', 'i', 'n', 's', 't')),
#  (2, ('e', 'g', 'g', 'l', 'r', 's', 't', 'u')),
#  (2, ('e', 'g', 'g', 'i', 'n', 'r', 's', 's')),
#  (2, ('e', 'g', 'g', 'i', 'l', 'r', 's', 'w')),
#  (2, ('e', 'g', 'g', 'i', 'l', 'n', 'r', 'u')),
#  (2, ('e', 'g', 'g', 'i', 'l', 'n', 'r', 's')),
#  (2, ('e', 'g', 'g', 'i', 'k', 'n', 'o', 's')),
#  (2, ('e', 'g', 'g', 'i', 'i', 'n', 'r', 'v')),
#  (2, ('e', 'f', 'o', 'o', 'p', 'r', 'r', 's')),
#  (2, ('e', 'f', 'n', 'o', 'o', 's', 's', 't')),
#  (2, ('e', 'f', 'm', 'o', 'p', 'r', 'r', 's')),
#  (2, ('e', 'f', 'm', 'n', 'r', 't', 'u', 'y')),
#  (2, ('e', 'f', 'l', 'r', 's', 't', 'u', 'u')),
#  (2, ('e', 'f', 'l', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'f', 'l', 'n', 'o', 's', 's', 'u')),
#  (2, ('e', 'f', 'i', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'f', 'i', 'r', 'r', 's', 't', 'u')),
#  (2, ('e', 'f', 'i', 'o', 'r', 'r', 's', 't')),
#  (2, ('e', 'f', 'i', 'm', 'n', 'o', 'r', 's')),
#  (2, ('e', 'f', 'i', 'l', 'r', 's', 's', 't')),
#  (2, ('e', 'f', 'i', 'l', 'r', 'r', 's', 't')),
#  (2, ('e', 'f', 'i', 'l', 'm', 's', 's', 't')),
#  (2, ('e', 'f', 'i', 'i', 'l', 'n', 't', 'y')),
#  (2, ('e', 'f', 'i', 'i', 'l', 'm', 's', 's')),
#  (2, ('e', 'f', 'h', 'i', 'i', 'n', 'r', 's')),
#  (2, ('e', 'f', 'g', 'i', 'n', 'r', 's', 'u')),
#  (2, ('e', 'f', 'g', 'i', 'n', 'r', 'r', 'y')),
#  (2, ('e', 'f', 'g', 'i', 'i', 'n', 'r', 'r')),
#  (2, ('e', 'f', 'g', 'i', 'i', 'n', 'n', 'r')),
#  (2, ('e', 'f', 'f', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'e', 'r', 'r', 's', 't', 't', 'u')),
#  (2, ('e', 'e', 'r', 'r', 's', 's', 't', 'w')),
#  (2, ('e', 'e', 'q', 'r', 's', 's', 't', 'u')),
#  (2, ('e', 'e', 'p', 'r', 'r', 's', 's', 'u')),
#  (2, ('e', 'e', 'o', 'r', 's', 's', 't', 'v')),
#  (2, ('e', 'e', 'o', 'r', 'r', 't', 'u', 'v')),
#  (2, ('e', 'e', 'o', 'r', 'r', 's', 't', 'v')),
#  (2, ('e', 'e', 'o', 'p', 'r', 's', 't', 't')),
#  (2, ('e', 'e', 'o', 'p', 'r', 's', 's', 'u')),
#  (2, ('e', 'e', 'o', 'p', 'r', 'r', 't', 'x')),
#  (2, ('e', 'e', 'n', 'o', 'p', 's', 's', 't')),
#  (2, ('e', 'e', 'n', 'o', 'p', 'p', 'r', 's')),
#  (2, ('e', 'e', 'n', 'n', 'o', 'r', 's', 't')),
#  (2, ('e', 'e', 'm', 'p', 'r', 'r', 's', 'u')),
#  (2, ('e', 'e', 'm', 'o', 'p', 'r', 'r', 's')),
#  (2, ('e', 'e', 'm', 'n', 's', 's', 't', 'u')),
#  (2, ('e', 'e', 'l', 'r', 's', 's', 't', 'w')),
#  (2, ('e', 'e', 'l', 'r', 's', 's', 's', 't')),
#  (2, ('e', 'e', 'l', 'p', 's', 's', 'u', 'x')),
#  (2, ('e', 'e', 'l', 'o', 's', 't', 'u', 'v')),
#  (2, ('e', 'e', 'l', 'o', 'r', 't', 'u', 'v')),
#  (2, ('e', 'e', 'l', 'o', 'r', 's', 'v', 'v')),
#  (2, ('e', 'e', 'l', 'o', 'p', 's', 't', 'u')),
#  (2, ('e', 'e', 'l', 'o', 'p', 'p', 's', 's')),
#  (2, ('e', 'e', 'l', 'n', 's', 't', 't', 'u')),
#  (2, ('e', 'e', 'l', 'n', 's', 's', 't', 'u')),
#  (2, ('e', 'e', 'l', 'n', 'o', 's', 's', 't')),
#  (2, ('e', 'e', 'l', 'n', 'o', 's', 's', 's')),
#  (2, ('e', 'e', 'l', 'm', 'o', 'r', 't', 'y')),
#  (2, ('e', 'e', 'l', 'm', 'o', 'p', 'r', 'y')),
#  (2, ('e', 'e', 'l', 'm', 'n', 'o', 'o', 's')),
#  (2, ('e', 'e', 'k', 'n', 'o', 's', 't', 'y')),
#  (2, ('e', 'e', 'k', 'l', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'j', 'n', 'o', 'r', 's', 'y')),
#  (2, ('e', 'e', 'i', 'r', 's', 's', 's', 'u')),
#  (2, ('e', 'e', 'i', 'r', 'r', 's', 't', 'v')),
#  (2, ('e', 'e', 'i', 'r', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'i', 'r', 'r', 'r', 's', 't')),
#  (2, ('e', 'e', 'i', 'q', 'r', 's', 't', 'u')),
#  (2, ('e', 'e', 'i', 'q', 'r', 'r', 's', 'u')),
#  (2, ('e', 'e', 'i', 'p', 'r', 'r', 't', 't')),
#  (2, ('e', 'e', 'i', 'p', 'q', 'r', 's', 'u')),
#  (2, ('e', 'e', 'i', 'o', 'p', 'r', 's', 't')),
#  (2, ('e', 'e', 'i', 'n', 's', 't', 't', 't')),
#  (2, ('e', 'e', 'i', 'n', 'r', 't', 't', 'y')),
#  (2, ('e', 'e', 'i', 'n', 'r', 's', 's', 'v')),
#  (2, ('e', 'e', 'i', 'n', 'q', 'r', 's', 'u')),
#  (2, ('e', 'e', 'i', 'n', 'p', 'r', 's', 'u')),
#  (2, ('e', 'e', 'i', 'n', 'p', 'r', 's', 's')),
#  (2, ('e', 'e', 'i', 'n', 'p', 'r', 'r', 's')),
#  (2, ('e', 'e', 'i', 'n', 'o', 's', 's', 's')),
#  (2, ('e', 'e', 'i', 'n', 'o', 'r', 's', 't')),
#  (2, ('e', 'e', 'i', 'n', 'o', 'p', 'r', 's')),
#  (2, ('e', 'e', 'i', 'n', 'n', 's', 't', 'w')),
#  (2, ('e', 'e', 'i', 'n', 'n', 'r', 't', 'v')),
#  (2, ('e', 'e', 'i', 'n', 'n', 'r', 's', 'v')),
#  (2, ('e', 'e', 'i', 'n', 'n', 'r', 's', 't')),
#  (2, ('e', 'e', 'i', 'm', 's', 's', 's', 't')),
#  (2, ('e', 'e', 'i', 'm', 'r', 's', 't', 't')),
#  (2, ('e', 'e', 'i', 'm', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'i', 'm', 'r', 'r', 't', 't')),
#  (2, ('e', 'e', 'i', 'm', 'p', 'r', 'r', 's')),
#  (2, ('e', 'e', 'i', 'm', 'o', 'p', 'r', 's')),
#  (2, ('e', 'e', 'i', 'm', 'n', 'o', 't', 'z')),
#  (2, ('e', 'e', 'i', 'm', 'n', 'o', 's', 't')),
#  (2, ('e', 'e', 'i', 'm', 'm', 'r', 's', 't')),
#  (2, ('e', 'e', 'i', 'l', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'i', 'l', 'n', 'r', 't', 'y')),
#  (2, ('e', 'e', 'i', 'l', 'n', 'r', 's', 'v')),
#  (2, ('e', 'e', 'i', 'l', 'n', 'p', 's', 't')),
#  (2, ('e', 'e', 'i', 'k', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'i', 'k', 'l', 'p', 's', 't')),
#  (2, ('e', 'e', 'i', 'i', 'n', 's', 't', 'v')),
#  (2, ('e', 'e', 'i', 'i', 'n', 'r', 't', 't')),
#  (2, ('e', 'e', 'i', 'i', 'l', 'm', 'n', 't')),
#  (2, ('e', 'e', 'h', 'l', 'o', 'p', 's', 't')),
#  (2, ('e', 'e', 'h', 'i', 's', 's', 's', 't')),
#  (2, ('e', 'e', 'h', 'i', 'n', 'p', 'r', 't')),
#  (2, ('e', 'e', 'h', 'i', 'n', 'n', 'q', 'u')),
#  (2, ('e', 'e', 'h', 'i', 'l', 'r', 's', 's')),
#  (2, ('e', 'e', 'g', 'i', 'r', 's', 't', 't')),
#  (2, ('e', 'e', 'g', 'i', 'n', 'n', 's', 'u')),
#  (2, ('e', 'e', 'g', 'i', 'm', 'n', 'r', 't')),
#  (2, ('e', 'e', 'g', 'i', 'm', 'm', 'r', 's')),
#  (2, ('e', 'e', 'g', 'i', 'l', 'o', 's', 'u')),
#  (2, ('e', 'e', 'g', 'i', 'l', 'n', 'r', 'v')),
#  (2, ('e', 'e', 'g', 'h', 'i', 'r', 's', 'w')),
#  (2, ('e', 'e', 'g', 'h', 'i', 'n', 's', 't')),
#  (2, ('e', 'e', 'g', 'g', 'i', 'n', 'n', 'r')),
#  (2, ('e', 'e', 'f', 'l', 'r', 's', 'u', 'x')),
#  (2, ('e', 'e', 'f', 'l', 'o', 'r', 'r', 'w')),
#  (2, ('e', 'e', 'f', 'i', 'n', 'r', 's', 't')),
#  (2, ('e', 'e', 'f', 'i', 'l', 'r', 'r', 't')),
#  (2, ('e', 'e', 'f', 'i', 'l', 'n', 'o', 's')),
#  (2, ('e', 'e', 'f', 'h', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'f', 'f', 'o', 'r', 'r', 's')),
#  (2, ('e', 'e', 'e', 'r', 'r', 's', 's', 'v')),
#  (2, ('e', 'e', 'e', 'p', 'r', 'r', 's', 'v')),
#  (2, ('e', 'e', 'e', 'n', 'r', 's', 'u', 'v')),
#  (2, ('e', 'e', 'e', 'l', 'r', 'r', 't', 't')),
#  (2, ('e', 'e', 'e', 'l', 'p', 'r', 's', 's')),
#  (2, ('e', 'e', 'e', 'k', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'e', 'i', 'p', 's', 's', 't')),
#  (2, ('e', 'e', 'e', 'i', 'n', 'r', 's', 't')),
#  (2, ('e', 'e', 'e', 'i', 'n', 'r', 's', 's')),
#  (2, ('e', 'e', 'e', 'i', 'n', 'n', 'r', 't')),
#  (2, ('e', 'e', 'e', 'i', 'l', 'n', 's', 't')),
#  (2, ('e', 'e', 'e', 'h', 'r', 's', 's', 't')),
#  (2, ('e', 'e', 'e', 'g', 'r', 'r', 's', 't')),
#  (2, ('d', 'o', 'o', 'p', 'r', 's', 't', 'u')),
#  (2, ('d', 'o', 'o', 'o', 'p', 'r', 's', 't')),
#  (2, ('d', 'n', 'n', 'o', 'r', 't', 'u', 'w')),
#  (2, ('d', 'm', 'o', 'o', 'o', 'r', 'w', 'w')),
#  (2, ('d', 'l', 'n', 'o', 'o', 's', 'w', 'w')),
#  (2, ('d', 'i', 'i', 'l', 'n', 'o', 't', 'u')),
#  (2, ('d', 'h', 'i', 'o', 'r', 's', 't', 'y')),
#  (2, ('d', 'h', 'i', 'm', 'o', 'r', 's', 'u')),
#  (2, ('d', 'g', 'i', 'n', 'o', 'r', 's', 'w')),
#  (2, ('d', 'g', 'i', 'n', 'n', 'o', 's', 'u')),
#  (2, ('d', 'g', 'i', 'l', 'l', 'n', 'o', 'r')),
#  (2, ('d', 'g', 'g', 'i', 'l', 'n', 'o', 's')),
#  (2, ('d', 'g', 'g', 'i', 'i', 'l', 'n', 'r')),
#  (2, ('d', 'g', 'g', 'g', 'i', 'n', 'r', 'u')),
#  (2, ('d', 'e', 'o', 'o', 'p', 'r', 's', 't')),
#  (2, ('d', 'e', 'n', 'o', 'r', 'r', 's', 'u')),
#  (2, ('d', 'e', 'n', 'o', 'p', 's', 't', 'u')),
#  (2, ('d', 'e', 'n', 'o', 'p', 'r', 's', 't')),
#  (2, ('d', 'e', 'm', 'n', 'o', 's', 't', 'u')),
#  (2, ('d', 'e', 'l', 'n', 'r', 's', 't', 'u')),
#  (2, ('d', 'e', 'l', 'n', 'o', 'r', 's', 'u')),
#  (2, ('d', 'e', 'l', 'n', 'o', 'o', 's', 'u')),
#  (2, ('d', 'e', 'l', 'm', 'o', 'r', 's', 'u')),
#  (2, ('d', 'e', 'l', 'l', 'o', 'r', 's', 't')),
#  (2, ('d', 'e', 'i', 'r', 's', 's', 's', 't')),
#  (2, ('d', 'e', 'i', 'p', 'r', 's', 't', 'u')),
#  (2, ('d', 'e', 'i', 'o', 'r', 's', 't', 'w')),
#  (2, ('d', 'e', 'i', 'o', 'r', 's', 't', 'u')),
#  (2, ('d', 'e', 'i', 'o', 'p', 's', 's', 't')),
#  (2, ('d', 'e', 'i', 'o', 'p', 'r', 's', 'v')),
#  (2, ('d', 'e', 'i', 'o', 'p', 'r', 's', 's')),
#  (2, ('d', 'e', 'i', 'n', 'r', 's', 't', 't')),
#  (2, ('d', 'e', 'i', 'n', 'r', 's', 's', 'u')),
#  (2, ('d', 'e', 'i', 'n', 'o', 'r', 's', 'u')),
#  (2, ('d', 'e', 'i', 'n', 'o', 'r', 's', 's')),
#  (2, ('d', 'e', 'i', 'n', 'o', 'o', 's', 'z')),
#  (2, ('d', 'e', 'i', 'm', 'o', 's', 's', 't')),
#  (2, ('d', 'e', 'i', 'm', 'o', 'o', 's', 't')),
#  (2, ('d', 'e', 'i', 'm', 'n', 'r', 't', 'u')),
#  (2, ('d', 'e', 'i', 'm', 'n', 'o', 'o', 't')),
#  (2, ('d', 'e', 'i', 'm', 'n', 'o', 'o', 's')),
#  (2, ('d', 'e', 'i', 'l', 'o', 's', 't', 'u')),
#  (2, ('d', 'e', 'i', 'l', 'o', 'p', 's', 's')),
#  (2, ('d', 'e', 'i', 'l', 'n', 't', 't', 'u')),
#  (2, ('d', 'e', 'i', 'l', 'n', 'r', 's', 't')),
#  (2, ('d', 'e', 'i', 'l', 'n', 'o', 'o', 's')),
#  (2, ('d', 'e', 'i', 'l', 'm', 'p', 's', 'u')),
#  (2, ('d', 'e', 'i', 'l', 'm', 'o', 's', 't')),
#  (2, ('d', 'e', 'i', 'l', 'm', 'o', 'r', 'u')),
#  (2, ('d', 'e', 'i', 'l', 'm', 'n', 's', 's')),
#  (2, ('d', 'e', 'i', 'l', 'l', 'r', 'r', 's')),
#  (2, ('d', 'e', 'i', 'i', 'n', 's', 's', 't')),
#  (2, ('d', 'e', 'i', 'i', 'n', 'o', 's', 't')),
#  (2, ('d', 'e', 'i', 'i', 'l', 'm', 's', 't')),
#  (2, ('d', 'e', 'h', 'n', 'o', 'o', 's', 'w')),
#  (2, ('d', 'e', 'h', 'l', 'o', 'o', 's', 't')),
#  (2, ('d', 'e', 'h', 'l', 'o', 'o', 'r', 'v')),
#  (2, ('d', 'e', 'h', 'i', 'n', 'o', 'p', 's')),
#  (2, ('d', 'e', 'h', 'i', 'm', 'n', 'o', 's')),
#  (2, ('d', 'e', 'h', 'i', 'l', 'o', 'p', 's')),
#  (2, ('d', 'e', 'h', 'i', 'i', 's', 't', 't')),
#  (2, ('d', 'e', 'h', 'i', 'i', 'l', 'l', 's')),
#  (2, ('d', 'e', 'g', 'n', 'o', 'r', 'r', 'u')),
#  (2, ('d', 'e', 'g', 'i', 'o', 'r', 's', 't')),
#  (2, ('d', 'e', 'g', 'i', 'n', 'r', 's', 'y')),
#  (2, ('d', 'e', 'g', 'i', 'n', 'r', 'r', 'y')),
#  (2, ('d', 'e', 'g', 'i', 'n', 'r', 'r', 's')),
#  (2, ('d', 'e', 'g', 'i', 'n', 'o', 's', 'w')),
#  (2, ('d', 'e', 'g', 'i', 'm', 'n', 'o', 's')),
#  (2, ('d', 'e', 'g', 'i', 'l', 'r', 's', 'u')),
#  (2, ('d', 'e', 'g', 'i', 'i', 'n', 'n', 't')),
#  (2, ('d', 'e', 'g', 'i', 'i', 'm', 'n', 'p')),
#  (2, ('d', 'e', 'g', 'h', 'i', 'l', 's', 't')),
#  (2, ('d', 'e', 'f', 'o', 'r', 's', 's', 't')),
#  (2, ('d', 'e', 'f', 'n', 'o', 'r', 's', 'u')),
#  (2, ('d', 'e', 'f', 'l', 'r', 's', 'u', 'u')),
#  (2, ('d', 'e', 'f', 'l', 'o', 'o', 'r', 's')),
#  (2, ('d', 'e', 'f', 'l', 'n', 'o', 'r', 'u')),
#  (2, ('d', 'e', 'f', 'i', 'o', 'p', 'r', 't')),
#  (2, ('d', 'e', 'f', 'i', 'l', 'm', 'n', 'u')),
#  (2, ('d', 'e', 'f', 'i', 'i', 'l', 'n', 's')),
#  (2, ('d', 'e', 'f', 'i', 'i', 'l', 'm', 's')),
#  (2, ('d', 'e', 'f', 'h', 'i', 'i', 'n', 's')),
#  (2, ('d', 'e', 'f', 'g', 'i', 'i', 'n', 'y')),
#  (2, ('d', 'e', 'f', 'g', 'i', 'i', 'l', 'n')),
#  (2, ('d', 'e', 'e', 'r', 's', 's', 's', 't')),
#  (2, ('d', 'e', 'e', 'o', 'r', 's', 't', 'y')),
#  (2, ('d', 'e', 'e', 'o', 'r', 's', 's', 't')),
#  (2, ('d', 'e', 'e', 'o', 'r', 'r', 'u', 'v')),
#  (2, ('d', 'e', 'e', 'o', 'r', 'r', 's', 't')),
#  (2, ('d', 'e', 'e', 'o', 'r', 'r', 'r', 's')),
#  (2, ('d', 'e', 'e', 'o', 'o', 'r', 's', 'v')),
#  (2, ('d', 'e', 'e', 'o', 'o', 'r', 'r', 'v')),
#  (2, ('d', 'e', 'e', 'n', 'r', 's', 'u', 'v')),
#  (2, ('d', 'e', 'e', 'm', 'r', 's', 't', 'u')),
#  (2, ('d', 'e', 'e', 'm', 'r', 'r', 'r', 'u')),
#  (2, ('d', 'e', 'e', 'm', 'n', 'o', 'o', 's')),
#  (2, ('d', 'e', 'e', 'l', 'p', 's', 'u', 'x')),
#  (2, ('d', 'e', 'e', 'l', 'p', 'r', 's', 'u')),
#  (2, ('d', 'e', 'e', 'l', 'o', 'r', 'r', 's')),
#  (2, ('d', 'e', 'e', 'l', 'o', 'p', 'r', 'x')),
#  (2, ('d', 'e', 'e', 'l', 'n', 'o', 'r', 't')),
#  (2, ('d', 'e', 'e', 'l', 'l', 'o', 'r', 'w')),
#  (2, ('d', 'e', 'e', 'l', 'l', 'n', 'o', 'r')),
#  (2, ('d', 'e', 'e', 'i', 'r', 'r', 't', 'v')),
#  (2, ('d', 'e', 'e', 'i', 'r', 'r', 's', 'v')),
#  (2, ('d', 'e', 'e', 'i', 'p', 's', 's', 't')),
#  (2, ('d', 'e', 'e', 'i', 'p', 'r', 's', 'v')),
#  (2, ('d', 'e', 'e', 'i', 'p', 'r', 's', 't')),
#  (2, ('d', 'e', 'e', 'i', 'o', 'r', 's', 'w')),
#  (2, ('d', 'e', 'e', 'i', 'o', 'p', 's', 't')),
#  (2, ('d', 'e', 'e', 'i', 'n', 's', 't', 't')),
#  (2, ('d', 'e', 'e', 'i', 'n', 's', 's', 'w')),
#  (2, ('d', 'e', 'e', 'i', 'n', 'r', 't', 'u')),
#  (2, ('d', 'e', 'e', 'i', 'n', 'r', 's', 'w')),
#  (2, ('d', 'e', 'e', 'i', 'n', 'r', 'r', 't')),
#  (2, ('d', 'e', 'e', 'i', 'n', 'n', 'u', 'v')),
#  (2, ('d', 'e', 'e', 'i', 'n', 'n', 's', 't')),
#  (2, ('d', 'e', 'e', 'i', 'm', 'r', 's', 't')),
#  (2, ('d', 'e', 'e', 'i', 'm', 'm', 'r', 's')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'r', 't', 't')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'o', 'r', 'v')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'o', 'r', 't')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'o', 'p', 't')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'n', 'u', 'v')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'n', 's', 's')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'n', 'o', 't')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'm', 'o', 's')),
#  (2, ('d', 'e', 'e', 'i', 'l', 'l', 'm', 'p')),
#  (2, ('d', 'e', 'e', 'h', 'o', 'r', 's', 'w')),
#  (2, ('d', 'e', 'e', 'h', 'n', 'o', 'r', 't')),
#  (2, ('d', 'e', 'e', 'h', 'i', 'r', 's', 'v')),
#  (2, ('d', 'e', 'e', 'g', 'l', 'o', 'r', 'w')),
#  (2, ('d', 'e', 'e', 'g', 'i', 'r', 's', 't')),
#  (2, ('d', 'e', 'e', 'g', 'i', 'n', 's', 't')),
#  (2, ('d', 'e', 'e', 'g', 'h', 'o', 't', 't')),
#  (2, ('d', 'e', 'e', 'g', 'g', 'i', 'n', 'r')),
#  (2, ('d', 'e', 'e', 'f', 'm', 'o', 'r', 'r')),
#  (2, ('d', 'e', 'e', 'f', 'i', 'l', 'r', 's')),
#  (2, ('d', 'e', 'e', 'f', 'i', 'i', 'r', 's')),
#  (2, ('d', 'e', 'e', 'f', 'f', 'n', 'o', 'r')),
#  (2, ('d', 'e', 'e', 'e', 'r', 's', 't', 't')),
#  (2, ('d', 'e', 'e', 'e', 'n', 'r', 'u', 'v')),
#  (2, ('d', 'e', 'e', 'e', 'n', 'p', 'r', 't')),
#  (2, ('d', 'e', 'e', 'e', 'm', 'n', 's', 's')),
#  (2, ('d', 'e', 'e', 'e', 'l', 'p', 's', 't')),
#  (2, ('d', 'e', 'e', 'e', 'l', 'n', 's', 's')),
#  (2, ('d', 'e', 'e', 'e', 'i', 'n', 'r', 's')),
#  (2, ('d', 'e', 'e', 'e', 'f', 'r', 'r', 'r')),
#  (2, ('d', 'd', 'i', 'i', 'm', 'r', 's', 'u')),
#  (2, ('d', 'd', 'g', 'i', 'n', 'p', 's', 'u')),
#  (2, ('d', 'd', 'e', 'i', 'r', 's', 't', 'u')),
#  (2, ('d', 'd', 'e', 'i', 'n', 'o', 's', 'w')),
#  (2, ('d', 'd', 'e', 'i', 'l', 'o', 'p', 's')),
#  (2, ('d', 'd', 'e', 'i', 'l', 'n', 's', 'w')),
#  (2, ('d', 'd', 'e', 'i', 'l', 'n', 'p', 's')),
#  (2, ('d', 'd', 'e', 'i', 'i', 'o', 's', 'x')),
#  (2, ('d', 'd', 'e', 'i', 'i', 'o', 'p', 's')),
#  (2, ('d', 'd', 'e', 'g', 'i', 'l', 'n', 'u')),
#  (2, ('d', 'd', 'e', 'e', 'n', 'r', 's', 'u')),
#  (2, ('d', 'd', 'e', 'e', 'm', 'r', 'r', 'u')),
#  (2, ('d', 'd', 'e', 'e', 'l', 'm', 'o', 'r')),
#  (2, ('d', 'd', 'e', 'e', 'i', 'p', 's', 's')),
#  (2, ('d', 'd', 'e', 'e', 'i', 'n', 'n', 't')),
#  (2, ('d', 'd', 'e', 'e', 'f', 'n', 'r', 'u')),
#  (2, ('d', 'd', 'e', 'e', 'e', 'f', 'n', 'r')),
#  (2, ('c', 'k', 'o', 'o', 'o', 's', 't', 'u')),
#  (2, ('c', 'i', 'l', 'r', 's', 't', 'u', 'y')),
#  (2, ('c', 'i', 'l', 'o', 'p', 'r', 'u', 'y')),
#  (2, ('c', 'i', 'l', 'o', 'o', 'r', 's', 't')),
#  (2, ('c', 'i', 'l', 'n', 'p', 's', 's', 'u')),
#  (2, ('c', 'i', 'l', 'n', 'o', 'o', 's', 't')),
#  (2, ('c', 'i', 'l', 'm', 'o', 'o', 'r', 's')),
#  (2, ('c', 'i', 'l', 'l', 'n', 'o', 's', 'u')),
#  (2, ('c', 'i', 'i', 'n', 'o', 'o', 's', 't')),
#  (2, ('c', 'i', 'i', 'm', 'n', 'o', 's', 't')),
#  (2, ('c', 'i', 'i', 'l', 'o', 's', 's', 't')),
#  (2, ('c', 'i', 'i', 'l', 'o', 'r', 's', 't')),
#  (2, ('c', 'i', 'i', 'l', 'n', 'o', 'p', 's')),
#  (2, ('c', 'i', 'i', 'k', 'n', 'p', 's', 't')),
#  (2, ('c', 'i', 'i', 'k', 'l', 'p', 's', 't')),
#  (2, ('c', 'h', 'i', 'n', 'o', 'o', 'r', 's')),
#  (2, ('c', 'h', 'i', 'i', 'o', 'r', 's', 't')),
#  (2, ('c', 'g', 'i', 'n', 's', 't', 't', 'u')),
#  (2, ('c', 'g', 'i', 'n', 'o', 'r', 's', 'u')),
#  (2, ('c', 'g', 'i', 'm', 'n', 'n', 'o', 'o')),
#  (2, ('c', 'g', 'i', 'l', 'n', 'o', 's', 'w')),
#  (2, ('c', 'g', 'i', 'l', 'm', 'n', 'u', 'u')),
#  (2, ('c', 'g', 'i', 'k', 'l', 'n', 's', 'u')),
#  (2, ('c', 'g', 'i', 'i', 'k', 'n', 's', 't')),
#  (2, ('c', 'g', 'h', 'i', 'n', 'r', 's', 'u')),
#  (2, ('c', 'g', 'h', 'i', 'n', 'o', 's', 'u')),
#  (2, ('c', 'g', 'h', 'i', 'i', 'l', 'n', 't')),
#  (2, ('c', 'f', 'i', 'm', 'n', 'o', 'r', 'u')),
#  (2, ('c', 'e', 'o', 'r', 's', 't', 'u', 'u')),
#  (2, ('c', 'e', 'o', 'r', 's', 's', 't', 'u')),
#  (2, ('c', 'e', 'o', 'r', 'r', 's', 's', 'u')),
#  (2, ('c', 'e', 'n', 'r', 's', 's', 't', 'u')),
#  (2, ('c', 'e', 'n', 'o', 's', 's', 't', 'u')),
#  (2, ('c', 'e', 'n', 'o', 'r', 's', 'u', 'u')),
#  (2, ('c', 'e', 'n', 'o', 'r', 'r', 's', 'w')),
#  (2, ('c', 'e', 'n', 'o', 'o', 'r', 'r', 's')),
#  (2, ('c', 'e', 'm', 'p', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'm', 'o', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'm', 'n', 'o', 'r', 's', 'u')),
#  (2, ('c', 'e', 'l', 'o', 'r', 's', 's', 'u')),
#  (2, ('c', 'e', 'l', 'o', 'p', 's', 't', 'u')),
#  (2, ('c', 'e', 'l', 'o', 'o', 'r', 's', 's')),
#  (2, ('c', 'e', 'l', 'o', 'o', 'r', 'r', 's')),
#  (2, ('c', 'e', 'l', 'n', 'o', 'o', 's', 's')),
#  (2, ('c', 'e', 'l', 'n', 'o', 'o', 'r', 's')),
#  (2, ('c', 'e', 'k', 'r', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'k', 'o', 'r', 's', 's', 't')),
#  (2, ('c', 'e', 'k', 'l', 'r', 's', 's', 'u')),
#  (2, ('c', 'e', 'i', 'r', 's', 's', 'u', 'v')),
#  (2, ('c', 'e', 'i', 'r', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'i', 'r', 'r', 's', 's', 'u')),
#  (2, ('c', 'e', 'i', 'o', 'r', 's', 't', 'x')),
#  (2, ('c', 'e', 'i', 'o', 'r', 's', 't', 'v')),
#  (2, ('c', 'e', 'i', 'o', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'i', 'n', 's', 's', 't', 'y')),
#  (2, ('c', 'e', 'i', 'n', 'r', 't', 't', 'u')),
#  (2, ('c', 'e', 'i', 'n', 'r', 's', 't', 't')),
#  (2, ('c', 'e', 'i', 'n', 'p', 'r', 's', 's')),
#  (2, ('c', 'e', 'i', 'n', 'o', 's', 't', 't')),
#  (2, ('c', 'e', 'i', 'n', 'o', 's', 's', 's')),
#  (2, ('c', 'e', 'i', 'n', 'o', 'r', 's', 't')),
#  (2, ('c', 'e', 'i', 'n', 'o', 'p', 'r', 's')),
#  (2, ('c', 'e', 'i', 'n', 'o', 'o', 't', 'z')),
#  (2, ('c', 'e', 'i', 'm', 'n', 'o', 'r', 's')),
#  (2, ('c', 'e', 'i', 'm', 'm', 'r', 's', 'u')),
#  (2, ('c', 'e', 'i', 'm', 'm', 'n', 'o', 'u')),
#  (2, ('c', 'e', 'i', 'l', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'i', 'l', 'p', 'p', 'r', 's')),
#  (2, ('c', 'e', 'i', 'l', 'o', 's', 's', 't')),
#  (2, ('c', 'e', 'i', 'l', 'o', 'p', 't', 'y')),
#  (2, ('c', 'e', 'i', 'l', 'o', 'p', 'r', 't')),
#  (2, ('c', 'e', 'i', 'l', 'n', 'o', 's', 't')),
#  (2, ('c', 'e', 'i', 'l', 'n', 'o', 'r', 's')),
#  (2, ('c', 'e', 'i', 'l', 'm', 'o', 'p', 'r')),
#  (2, ('c', 'e', 'i', 'k', 'q', 's', 't', 'u')),
#  (2, ('c', 'e', 'i', 'k', 'l', 's', 's', 't')),
#  (2, ('c', 'e', 'i', 'k', 'l', 'n', 'r', 's')),
#  (2, ('c', 'e', 'i', 'k', 'k', 'l', 'o', 'r')),
#  (2, ('c', 'e', 'i', 'i', 'p', 'r', 's', 't')),
#  (2, ('c', 'e', 'i', 'i', 'n', 's', 't', 'z')),
#  (2, ('c', 'e', 'i', 'i', 'n', 'r', 's', 'u')),
#  (2, ('c', 'e', 'i', 'i', 'n', 'o', 'r', 's')),
#  (2, ('c', 'e', 'i', 'i', 'n', 'n', 'o', 's')),
#  (2, ('c', 'e', 'i', 'i', 'm', 'o', 's', 't')),
#  (2, ('c', 'e', 'i', 'i', 'l', 'n', 'o', 's')),
#  (2, ('c', 'e', 'i', 'i', 'j', 's', 't', 'u')),
#  (2, ('c', 'e', 'h', 'o', 'r', 's', 't', 'u')),
#  (2, ('c', 'e', 'h', 'o', 'r', 's', 's', 'u')),
#  (2, ('c', 'e', 'h', 'o', 'o', 'r', 's', 'u')),
#  (2, ('c', 'e', 'h', 'o', 'o', 'r', 's', 's')),
#  (2, ('c', 'e', 'h', 'n', 'n', 'o', 's', 'u')),
#  (2, ('c', 'e', 'h', 'm', 'o', 'o', 's', 's')),
#  (2, ('c', 'e', 'h', 'i', 'r', 's', 't', 't')),
#  (2, ('c', 'e', 'h', 'i', 'o', 'r', 't', 'u')),
#  (2, ('c', 'e', 'h', 'i', 'o', 'r', 'r', 't')),
#  (2, ('c', 'e', 'h', 'i', 'o', 'p', 's', 't')),
#  (2, ('c', 'e', 'h', 'i', 'o', 'p', 'r', 'u')),
#  (2, ('c', 'e', 'h', 'i', 'o', 'o', 'r', 's')),
#  ...]

# %% [markdown]
# # Quick poll
# About how long did you spend working on this Reading Journal?

# %%
2 hours
# Out:
#   File "<ipython-input-151-e4c25cf6260c>", line 1
#     2 hours
#           ^
# SyntaxError: invalid syntax
